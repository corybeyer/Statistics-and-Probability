# %%
import numpy as np
import pandas as pd
from scipy.stats import linregress

np.random.seed(1997)
df = pd.DataFrame(pd.np.random.rand(100, 10))

df['Intercept']= df.apply(lambda x: linregress(range(0,len(df.columns)), x).intercept,axis=1)
df['Slope'] = df.apply(lambda x: linregress(range(0,len(df.columns)), x).slope,axis=1)
# Out:
# <ipython-input-34-8677b8235867>:6: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df = pd.DataFrame(pd.np.random.rand(100, 10))

# %%
df
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.771148  0.074757  0.526310  0.975088  0.992226  0.465135  0.611135
# 1   0.875238  0.399760  0.972751  0.218071  0.066720  0.576635  0.559610
# 2   0.363943  0.430937  0.479464  0.530325  0.325569  0.912511  0.843324
# 3   0.481345  0.220094  0.629562  0.003211  0.802209  0.584688  0.633781
# 4   0.287090  0.481329  0.046301  0.288716  0.702347  0.849911  0.346053
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.678642  0.012072  0.934410  0.226034  0.932351  0.512133  0.837719
# 96  0.555435  0.431810  0.820311  0.055326  0.251342  0.155167  0.672619
# 97  0.796300  0.355642  0.639037  0.616372  0.568212  0.802409  0.843010
# 98  0.379716  0.349512  0.985946  0.555202  0.336363  0.439133  0.006734
# 99  0.093746  0.550755  0.610305  0.391584  0.658611  0.931838  0.056777
#
#            7         8         9  Intercept     Slope
# ...

# %%
for vals in
